# %% [markdown]
# # Plotting Graphs between different columns of dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from joblib import Parallel, delayed
import multiprocessing
import _thread
import time
from datetime import datetime

# %%
df1 = pd.read_csv(r"creditcard.csv", index_col=0, parse_dates=True, dtype='unicode')
df = df1.iloc[1:500, :]

# %%
#random undersampling
#class_0_under = class_0.sample(class_count_1)
#test_under = pd.concat([class_0_under, class_1], axis=0)
#print("total class of 1 and 0:\n", test_under[ 'Class'].value_counts())
# plot the count after under-sampeling 
#test_under ['Class'].value_counts().plot(kind='bar', title='count (target)')

# %%
print(df1)
# Out:
#           Time                  V1                   V2                 V3  \
# 0            0    -1.3598071336738  -0.0727811733098497   2.53634673796914
# 1            0    1.19185711131486     0.26615071205963   0.16648011335321
# 2            1   -1.35835406159823    -1.34016307473609   1.77320934263119
# 3            1  -0.966271711572087   -0.185226008082898   1.79299333957872
# 4            2   -1.15823309349523    0.877736754848451     1.548717846511
# ...        ...                 ...                  ...                ...
# 284802  172786   -11.8811178854323     10.0717849710003  -9.83478345739033
# 284803  172787  -0.732788670658956  -0.0550804899173326   2.03502974528243
# 284804  172788    1.91956500980048   -0.301253845990644  -3.24963981406834
# 284805  172788  -0.240440049680947    0.530482513118839  0.702510230095103
# 284806  172792   -0.53341252200504   -0.189733337002305  0.703337366963779
#
# ...

# %%
fig = plt.figure(figsize = (15, 12))
def plot1():
    plt.subplot(5, 6, 1) ; plt.plot(df.V1) ; plt.subplot(5, 6, 15) ; plt.plot(df.V15)
def plot2():
    plt.subplot(5, 6, 2) ; plt.plot(df.V2) ; plt.subplot(5, 6, 16) ; plt.plot(df.V16)
def plot3():
    plt.subplot(5, 6, 3) ; plt.plot(df.V3) ; plt.subplot(5, 6, 17) ; plt.plot(df.V17)
def plot4():
    plt.subplot(5, 6, 4) ; plt.plot(df.V4) ; plt.subplot(5, 6, 18) ; plt.plot(df.V18)
def plot5():
    plt.subplot(5, 6, 5) ; plt.plot(df.V5) ; plt.subplot(5, 6, 19) ; plt.plot(df.V19)
def plot6():
    plt.subplot(5, 6, 6) ; plt.plot(df.V6) ; plt.subplot(5, 6, 20) ; plt.plot(df.V20)
def plot7():
    plt.subplot(5, 6, 7) ; plt.plot(df.V7) ; plt.subplot(5, 6, 21) ; plt.plot(df.V21)
def plot8():
    plt.subplot(5, 6, 8) ; plt.plot(df.V8) ; plt.subplot(5, 6, 22) ; plt.plot(df.V22)
def plot9():
    plt.subplot(5, 6, 9) ; plt.plot(df.V9) ; plt.subplot(5, 6, 23) ; plt.plot(df.V23)
def plot10():
    plt.subplot(5, 6, 10) ; plt.plot(df.V10) ; plt.subplot(5, 6, 24) ; plt.plot (df.V24)
def plot11():
    plt.subplot(5, 6, 11) ; plt.plot(df.V11) ; plt.subplot(5, 6, 25) ; plt.plot(df.V25)
def plot12():
    plt.subplot(5, 6, 12) ; plt.plot(df.V12) ; plt.subplot(5, 6, 26) ; plt.plot (df.V26)
def plot13():
    plt.subplot(5, 6, 13) ; plt.plot(df.V13) ; plt.subplot(5, 6, 27) ; plt.plot(df.V27)
def plot14():
    plt.subplot(5, 6, 14) ; plt.plot(df.V14) ; plt.subplot(5, 6, 28) ; plt.plot (df.V28)
def plot15():
    plt.subplot(5, 6, 29) ; plt.plot(df.Amount)

# %%
start_time = datetime.now()
plot1()
plot2()
plot3()
plot4()
plot5()
plot6()
plot7()
plot8()
plot9()
plot10()
plot11()
plot12()
plot13()
plot14()
plot15()
plt.show()   
end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))
# Out:
# Duration: 0:13:43.793801

# %%
start_time = datetime.now()

try: 
    _thread.start_new_thread(plot1,())
    _thread.start_new_thread(plot2,())
    _thread.start_new_thread(plot3,())
    _thread.start_new_thread(plot4,())
    _thread.start_new_thread(plot5,())
    _thread.start_new_thread(plot6,())
    _thread.start_new_thread(plot7,())
    _thread.start_new_thread(plot8,())
    _thread.start_new_thread(plot9,())
    _thread.start_new_thread(plot10,())
    _thread.start_new_thread(plot11,())
    _thread.start_new_thread(plot12,())
    _thread.start_new_thread(plot13,())
    _thread.start_new_thread(plot14,())
    _thread.start_new_thread(plot15,())
except: 
    print("Unable to start thread")
plt.show()   
end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))
# Out:
# Duration: 0:09:35.130959

# %%
import sys
import numpy
import pandas
import matplotlib
import seaborn
import scipy
import sklearn

print("python :{}".format(sys.version))
print("numpy :{}".format(numpy.__version__))
print("pandas :{}".format(pandas.__version__))
print("pmatplotlib :{}".format(matplotlib.__version__))
print("seaborn :{}".format(seaborn.__version__))
print("scipy :{}".format(scipy.__version__))
# Out:
# python :3.9.6 (tags/v3.9.6:db3ff76, Jun 28 2021, 15:26:21) [MSC v.1929 64 bit (AMD64)]
# numpy :1.19.5
# pandas :1.3.1
# pmatplotlib :3.4.3
# seaborn :0.11.2
# scipy :1.7.1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("creditcard.csv")

# %%
print(data.columns)
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
print(data.shape)
# Out:
# (284807, 31)

# %%
print(data.describe())
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
data=data.sample(frac=0.1,random_state=1)
print(data.shape)
# Out:
# (28481, 31)

# %%
data.hist(figsize=(20,20))
plt.show()
